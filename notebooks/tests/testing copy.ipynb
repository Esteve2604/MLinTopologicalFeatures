# %% [markdown]
# First we are gonna read all the sample and to extract the shortest length

# %%
# !pip install matplotlib
# !pip install giotto-tda
# !pip install numpy
# !pip install scipy
# !pip install ipykernel
# !pip install --upgrade nbformat

# !pip install dtaidistance
# !pip install pandas openpyxl
# !pip install Cython
# !pip install Ripser
# Out:
# Collecting Cython
#   Downloading Cython-3.0.12-cp311-cp311-win_amd64.whl.metadata (3.6 kB)
# Downloading Cython-3.0.12-cp311-cp311-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/2.8 MB 7.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.7/2.8 MB 9.2 MB/s eta 0:00:01
#    ------------------ --------------------- 1.3/2.8 MB 10.3 MB/s eta 0:00:01
#    -------------------------- ------------- 1.8/2.8 MB 10.7 MB/s eta 0:00:01
#    --------------------------------- ------ 2.3/2.8 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 10.4 MB/s eta 0:00:00
# Installing collected packages: Cython
# Successfully installed Cython-3.0.12
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting Ripser
#   Downloading ripser-0.6.12-cp311-cp311-win_amd64.whl.metadata (8.9 kB)
# Requirement already satisfied: Cython in c:\users\esteb\appdata\local\programs\python\python311\lib\site-packages (from Ripser) (3.0.12)
# Requirement already satisfied: numpy in c:\users\esteb\appdata\local\programs\python\python311\lib\site-packages (from Ripser) (1.26.4)
# Collecting persim (from Ripser)
#   Downloading persim-0.3.8-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: scipy in c:\users\esteb\appdata\local\programs\python\python311\lib\site-packages (from Ripser) (1.14.1)
# Requirement already satisfied: scikit-learn in c:\users\esteb\appdata\local\programs\python\python311\lib\site-packages (from Ripser) (1.3.2)
# Collecting deprecated (from persim->Ripser)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting hopcroftkarp (from persim->Ripser)
#   Downloading hopcroftkarp-1.2.5.tar.gz (16 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: joblib in c:\users\esteb\appdata\local\programs\python\python311\lib\site-packages (from persim->Ripser) (1.4.2)
# Requirement already satisfied: matplotlib in c:\users\esteb\appdata\local\programs\python\python311\lib\site-packages (from persim->Ripser) (3.9.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\esteb\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->Ripser) (3.5.0)
# Collecting wrapt<2,>=1.10 (from deprecated->persim->Ripser)
#   Downloading wrapt-1.17.2-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\esteb\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->persim->Ripser) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\esteb\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->persim->Ripser) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\esteb\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->persim->Ripser) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\esteb\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->persim->Ripser) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\esteb\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->persim->Ripser) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\esteb\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->persim->Ripser) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\esteb\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->persim->Ripser) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\esteb\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->persim->Ripser) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\esteb\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib->persim->Ripser) (1.16.0)
# Downloading ripser-0.6.12-cp311-cp311-win_amd64.whl (150 kB)
#    ---------------------------------------- 0.0/150.5 kB ? eta -:--:--
#    ---------------------------------------- 150.5/150.5 kB 4.5 MB/s eta 0:00:00
# Downloading persim-0.3.8-py3-none-any.whl (48 kB)
#    ---------------------------------------- 0.0/48.6 kB ? eta -:--:--
#    ---------------------------------------- 48.6/48.6 kB 2.6 MB/s eta 0:00:00
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading wrapt-1.17.2-cp311-cp311-win_amd64.whl (38 kB)
# Building wheels for collected packages: hopcroftkarp
#   Building wheel for hopcroftkarp (pyproject.toml): started
#   Building wheel for hopcroftkarp (pyproject.toml): finished with status 'done'
#   Created wheel for hopcroftkarp: filename=hopcroftkarp-1.2.5-py2.py3-none-any.whl size=18176 sha256=aedcd4902f8e21be2b753461627b52543217fcb10b5d2ac1dbd48cc47d97ee11
#   Stored in directory: c:\users\esteb\appdata\local\pip\cache\wheels\1f\cc\2d\de23a8b9ae586817b0b44de4a4b1a08f23473e248a644b312f
# Successfully built hopcroftkarp
# Installing collected packages: hopcroftkarp, wrapt, deprecated, persim, Ripser
# Successfully installed Ripser-0.6.12 deprecated-1.2.18 hopcroftkarp-1.2.5 persim-0.3.8 wrapt-1.17.2
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from scipy.io import wavfile
import os
import matplotlib.pyplot as plt
import numpy as np


directory = './vowels/Control/A'

shortestLength = 9999
allSampleRate = -1
allSameSampleRate = True

actualStartOfFilename = ''
aggregate = True
aggregatedVoices = []
for filename in os.listdir(directory):
    startOfFilename = filename.split('a')[0]
    if(actualStartOfFilename != startOfFilename):
        aggregate = False
        actualStartOfFilename = startOfFilename
    f = os.path.join(directory, filename)
    samplerate, data = wavfile.read(f)
    length = data.shape[0] / samplerate
    allSampleRate = samplerate if allSampleRate == -1 else samplerate
    allSameSampleRate = samplerate == allSampleRate
    shortestLength = length if shortestLength > length else shortestLength
    
    

print(f"All the audios have the same sample rate: {allSameSampleRate}")
print(f"The sample rate is {allSampleRate} data per second")
print(f"The shortest audio length is {shortestLength}")
print(f"The number of data per audio to analyse is {shortestLength*samplerate}")
# Out:
# All the audios have the same sample rate: True
# The sample rate is 44100 data per second
# The shortest audio length is 0.677641723356009
# The number of data per audio to analyse is 29884.0

# %%
from dtaidistance import dtw_barycenter
# We aggregate the three audio files. As an idea it would be to short the signal between the three audios instead of in general
actualStartOfFilename = ''
aggregate = True
aggregatedVoices = []
voicesToAggregate = []
numberOfFilesMixed = 0
for filename in os.listdir(directory):
    startOfFilename = filename.split('a')[0]
    if(actualStartOfFilename != startOfFilename):
        aggregate = False
       
    f = os.path.join(directory, filename)
    samplerate, data = wavfile.read(f)
    if(aggregate):
        numberOfFilesMixed += 1
        voicesToAggregate.append(data.astype(np.float64))
        # aggregatedVoices[len(aggregatedVoices)-1] += data[:int(shortestLength*samplerate)] # To do simple mean

    else:
        if(len(voicesToAggregate) > 0):
            #  aggregatedVoices[len(aggregatedVoices)-1]  =  (actualStartOfFilename, aggregatedVoices[len(aggregatedVoices)-1] / numberOfFilesMixed) # For simple mean
            aggregatedVoice = dtw_barycenter.dba(voicesToAggregate,voicesToAggregate[0], use_c=True)
            aggregatedVoices.append(aggregatedVoice[:int(shortestLength*samplerate)])
            
        numberOfFilesMixed = 1
        aggregate=True
        voicesToAggregate = []
        voicesToAggregate.append(data.astype(np.float64))
        actualStartOfFilename = startOfFilename
    
    #A last iteration is needed for the last element
# aggregatedVoices[len(aggregatedVoices)-1]  =  (actualStartOfFilename, aggregatedVoices[len(aggregatedVoices)-1] / numberOfFilesMixed) 
aggregatedVoice = dtw_barycenter.dba(voicesToAggregate,voicesToAggregate[0], use_c=True)
aggregatedVoices.append(aggregatedVoice[:int(shortestLength*samplerate)])

# %% [markdown]
# Now we use the gtda code following the tutorial

# %%
# tda magic
from gtda.homology import VietorisRipsPersistence, CubicalPersistence
from gtda.diagrams import PersistenceEntropy, Scaler
from gtda.plotting import plot_heatmap, plot_point_cloud, plot_diagram
from gtda.pipeline import Pipeline
from gtda.time_series import SingleTakensEmbedding, TakensEmbedding
# This does a fixed embedding
# embedding_dimension_periodic = 3
# embedding_time_delay_periodic = 8
# stride = 10

# embedder_periodic = SingleTakensEmbedding(
#     parameters_type="fixed",
#     n_jobs=-1,
#     time_delay=embedding_time_delay_periodic,
#     dimension=embedding_dimension_periodic,
#     stride=stride,
# )
#This looks for the best embedding to represent the time series
embedding_dimension = 7
embedding_time_delay = 23
stride = 1
dimensionsAndTimeDelays = []

for filename, data in aggregatedVoices:
    #Lots of memory is needed with stride 1 and multiple jobs, change with caution

    embedder = SingleTakensEmbedding(
        parameters_type="fixed", n_jobs=8, time_delay=embedding_time_delay, dimension=embedding_dimension, stride=stride
    )
    embedded_signal = embedder.fit_transform(data)
    # # This code saves the embedding, with the first row of the text being the dimension and time_delay used
    # arr0 = [0] * embedder.dimension_
    # arr0[0] = embedder.dimension_
    # arr0[1] = embedder.time_delay_
    # savingArray = np.concatenate(([arr0], embedded_signal))

    savingDirectory = "./embeddedVowels"
    # Create the directory if it doesn't exist
    os.makedirs(savingDirectory, exist_ok=True)

    savingDirectory = savingDirectory + "/" + directory.split('/')[2] 
 
    # Create the directory if it doesn't exist
    os.makedirs(savingDirectory, exist_ok=True)
    savingDirectory = savingDirectory + "/" + directory.split('/')[3] 


    # Create the directory if it doesn't exist
    os.makedirs(savingDirectory, exist_ok=True)

    # Construct the full path for the file
    savingFilename = savingDirectory + "/"+  filename.split('.wav')[0] + 'embedding.csv'
   
    with open(savingFilename, 'wb') as f:
        np.savetxt(f, embedded_signal, delimiter=',')
        print('File ' + savingFilename + ' saved correctly')
# Out:
# File ./embeddedVowels/Control/A/AVPEPUDEAC0001embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0003embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0004embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0005embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0006embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0007embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0008embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0010embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0011embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0012embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0013embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0014embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0015embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0016embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0017embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0018embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0019embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0020embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0021embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0022embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0023embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0024embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0025embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0026embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0027embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0028embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0029embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0030embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0031embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0033embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0034embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0035embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0037embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0039embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0040embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0041embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0042embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0043embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0044embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0045embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0046embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0047embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0048embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0049embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0050embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0051embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0052embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0053embedding.csvsaved correctly
# File ./embeddedVowels/Control/A/AVPEPUDEAC0054embedding.csvsaved correctly
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 25
#      21 embedding_time_delay = 30
#      22 stride = 1
# ---> 25 for filename, data in aggregatedVoices:
#      26     #Lots of memory is needed with stride 1 and multiple jobs, change with caution
#      28     embedder = SingleTakensEmbedding(
#      29         parameters_type="search", n_jobs=8, time_delay=embedding_time_delay, dimension=embedding_dimension, stride=stride
#      30     )
#      31     embedded_signal = embedder.fit_transform(data)
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# Persistence Diagram

# %%
homology_dimensions = [0, 1, 2]

y_periodic_embedded = y_periodic_embedded[None, :, :]
periodic_persistence = VietorisRipsPersistence(homology_dimensions=homology_dimensions, n_jobs=6)
# %time periodic_persistence_diagrams = periodic_persistence.fit_transform(y_periodic_embedded)
# Out:
# CPU times: total: 2.88 s
# Wall time: 19min 22s

# %%
from gtda.plotting import plot_diagram
import numpy as np

embeddedVowel = np.loadtxt('./pDTestRips4000distReduction5/Prueba2/O/AVPEPUDEAC0001PersistenceDiagram.csv',delimiter=",", dtype=np.float64, skiprows=1)
plot_diagram(embeddedVowel)
